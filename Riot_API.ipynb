# %%
import requests 
api_key = 'RGAPI-dfcefd7e-9374-428d-b8fc-5b14fe1e0643'
api_url = 'https://vn2.api.riotgames.com/tft/summoner/v1/summoners/by-name/GettingCloser'
api_url = api_url + '?api_key=' + api_key

# %%
resp = requests.get(api_url)

# %%
player_info = resp.json()
player_info
# Out:
# {'id': '_x5j4IlfbdCoOlZI3daPI5odtef_NYIf2t2hEgcNkFLw-XIPZUH_kYLfUA',
#  'accountId': 'dKRFDDJuDVEX8rR7KSz-Htqk8b_5U0VqgHnXQneQfAimygYCiuSb1I83',
#  'puuid': 'JhuCYEWyUKtUHwtYk9JsCkthOK_Ga_t4lPLwa03PqgbvFEre_f22LDVFz-3ZtDnqWR2ZUpclkt4olA',
#  'name': 'GettingCloser',
#  'profileIconId': 5663,
#  'revisionDate': 1699984894350,
#  'summonerLevel': 299}

# %%
puuid = 'JhuCYEWyUKtUHwtYk9JsCkthOK_Ga_t4lPLwa03PqgbvFEre_f22LDVFz-3ZtDnqWR2ZUpclkt4olA'
accountid = 'dKRFDDJuDVEX8rR7KSz-Htqk8b_5U0VqgHnXQneQfAimygYCiuSb1I83'

# %%
api_url3 = 'https://sea.api.riotgames.com/tft/match/v1/matches/by-puuid/JhuCYEWyUKtUHwtYk9JsCkthOK_Ga_t4lPLwa03PqgbvFEre_f22LDVFz-3ZtDnqWR2ZUpclkt4olA/ids?start=0&count=20&api_key=RGAPI-dfcefd7e-9374-428d-b8fc-5b14fe1e0643'
resp2 = requests.get(api_url3)
match_info = resp2.json()
match_info
# Out:
# ['VN2_232456739',
#  'VN2_232333134',
#  'VN2_232147055',
#  'VN2_231817618',
#  'VN2_231810858',
#  'VN2_231799685',
#  'VN2_231775657',
#  'VN2_231079637',
#  'VN2_231056955',
#  'VN2_222183756',
#  'VN2_221710080',
#  'VN2_221085195',
#  'VN2_220965159',
#  'VN2_220620862',
#  'VN2_220247595',
#  'VN2_220230166',
#  'VN2_219954010',
#  'VN2_219763087',
#  'VN2_219109804',
#  'VN2_218713001']

# %%
api_url4 = 'https://sea.api.riotgames.com/tft/match/v1/matches/VN2_232456739?api_key=RGAPI-dfcefd7e-9374-428d-b8fc-5b14fe1e0643'
resp2 = requests.get(api_url4)
match_data = resp2.json()
match_data
# Out:
# {'metadata': {'data_version': '5',
#   'match_id': 'VN2_232456739',
#   'participants': ['HLvbp3_XFiJmFdsRetMJ_25ej7GolrqZrdRa3GErpSdv7RdlhuygpjHQ2gpdIMAKlTRG5rVQxAmBVQ',
#    'JhuCYEWyUKtUHwtYk9JsCkthOK_Ga_t4lPLwa03PqgbvFEre_f22LDVFz-3ZtDnqWR2ZUpclkt4olA',
#    'xKAQLBDXJKjLhfwXd-nLDqOVWwdiVYRsHVzh3r-pDcGhQpmn8OmuVNWI7toMYc-J3yO6CFKXE0MSlA',
#    'nhY88XWqP4xNQDGeI59gBSZSrJTVKnyYBC9LirdXIXqEhGTk9I6XezKvhfjsOyF7NM_JA546haGaqw',
#    'AtWzGmH2KB9j6yUM3u-oyu0RA7_pyEwi3NNsv91LWUyleZDHA5SM0YIfxogOQcagIMCKR1mboUkDKw',
#    'm0BW5ma4QP6qUmpOisqdwdbJGzpKhluHk8omBVnHBHXMtZ69IklqYAQ8wimjJ-Ns8438PDFkehwGNw',
#    'xPfQEeVRWK4gfwrG1yQzX08tVG6jVxlofSCgYC4efc4DsLmc_ca_Kp4XtQjy3Zq2C1zlKkBQmdJIgg',
#    'dF7UhQvCazh3CtgHtcku3RwdMxjsB5PdxSCpjUK4Vl4qTZ2ps_dlGM3F5XffflnBs7Uc2UxjT-mIOQ']},
#  'info': {'game_datetime': 1699984858887,
#   'game_length': 1344.537353515625,
#   'game_version': 'Version 13.22.541.9804 (Nov 08 2023/01:52:34) [PUBLIC] <Releases/13.22>',
# ...

# %%
match_data
# Out:
# {'metadata': {'data_version': '5',
#   'match_id': 'VN2_232456739',
#   'participants': ['HLvbp3_XFiJmFdsRetMJ_25ej7GolrqZrdRa3GErpSdv7RdlhuygpjHQ2gpdIMAKlTRG5rVQxAmBVQ',
#    'JhuCYEWyUKtUHwtYk9JsCkthOK_Ga_t4lPLwa03PqgbvFEre_f22LDVFz-3ZtDnqWR2ZUpclkt4olA',
#    'xKAQLBDXJKjLhfwXd-nLDqOVWwdiVYRsHVzh3r-pDcGhQpmn8OmuVNWI7toMYc-J3yO6CFKXE0MSlA',
#    'nhY88XWqP4xNQDGeI59gBSZSrJTVKnyYBC9LirdXIXqEhGTk9I6XezKvhfjsOyF7NM_JA546haGaqw',
#    'AtWzGmH2KB9j6yUM3u-oyu0RA7_pyEwi3NNsv91LWUyleZDHA5SM0YIfxogOQcagIMCKR1mboUkDKw',
#    'm0BW5ma4QP6qUmpOisqdwdbJGzpKhluHk8omBVnHBHXMtZ69IklqYAQ8wimjJ-Ns8438PDFkehwGNw',
#    'xPfQEeVRWK4gfwrG1yQzX08tVG6jVxlofSCgYC4efc4DsLmc_ca_Kp4XtQjy3Zq2C1zlKkBQmdJIgg',
#    'dF7UhQvCazh3CtgHtcku3RwdMxjsB5PdxSCpjUK4Vl4qTZ2ps_dlGM3F5XffflnBs7Uc2UxjT-mIOQ']},
#  'info': {'game_datetime': 1699984858887,
#   'game_length': 1344.537353515625,
#   'game_version': 'Version 13.22.541.9804 (Nov 08 2023/01:52:34) [PUBLIC] <Releases/13.22>',
# ...
